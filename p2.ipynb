# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv('datasets/customer_churn.csv')

# %%
plt.rcParams['figure.figsize'] = [5,5]

plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Bar graph sir')
plt.bar(data['Gender'],data['Age'])
# Out:
# <BarContainer object of 10000 artists>

# %% [markdown]
# Histogram

# %%
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.hist(data['Age'],edgecolor='black') #by default it takes bin as 10.
plt.show()

# %% [markdown]
# Pie chart

# %%
labels = 'IT', 'Marketing', 'Data Science', 'Finance'
values = [500, 150, 300, 510]
explode = (0.05, 0.05, 0.05, 0.05)

#plt.pie(values, labels=labels)
plt.pie(values, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True)
plt.show()

# %% [markdown]
# Acitivity in Class

# %%
df = pd.read_csv('datasets/titanic_data.csv')

labels = '1st Class', '2nd Class', '3rd Class'
values = df['Pclass'].value_counts()
explode = (0.05, 0.05, 0.05)

plt.pie(values, labels=labels, autopct='%1.1f%%', shadow=True, explode=explode)
plt.show()

# %% [markdown]
# Stack Area Chart

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
London = [25, 26, 32, 19, 28, 39, 24]
Tokyo = [20, 29, 23, 35, 32, 26, 18]
Paris = [18, 21, 28, 35, 29, 25, 22]

plt.figure(figsize=(10, 6))
plt.stackplot(days, London, Tokyo, Paris, labels=["London", "Tokyo", "Paris"], colors=["green", "white", "orange"], alpha=0.8)
plt.xlabel("Days of the Week", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.title('Days of Week v/s Temperature')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Stack Bar Chart

# %% [markdown]
# Activity

# %%
x_vals = np.linspace(0, 20, 20)
y_vals = x_vals ** 2

plt.rcParams['figure.figsize'] = [9,9]

plt.subplot(2,2,1)
plt.plot(x_vals,y_vals,color='r',marker='X')
plt.xlabel('X')
plt.ylabel('Y')

plt.subplot(2,2,2)
plt.plot(x_vals,y_vals,color='b',marker='+')
plt.xlabel('X')
plt.ylabel('Y')

plt.subplot(2,2,3)
plt.plot(x_vals,y_vals,color='g',marker='_')
plt.xlabel('X')
plt.ylabel('Y')

plt.subplot(2,2,4)
plt.plot(x_vals,y_vals,color='orange',marker='*')
plt.xlabel('X')
plt.ylabel('Y')

#to save a graph in picture
#plt.savefig(r"sigma_graph.jpg")
# Out:
# Text(0, 0.5, 'Y')
