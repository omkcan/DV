# %% [markdown]
# Titanic Dataset (Passenger Survival Analysis)

# %%
#Global Imports
import matplotlib.pyplot as plt
import seaborn as sns

titanic = sns.load_dataset("titanic")

# %%
#Preview of the dataset
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Q1. Create a Barplot

# %%
plt.figure(figsize=(10, 6))
g = sns.countplot(y='pclass', hue='survived', data=titanic, palette=['red', 'green'])

plt.title("Survival Count by Passenger Class")
plt.ylabel("Passenger Class")
plt.xlabel("Count")         
plt.yticks(ticks=[0, 1, 2], labels=["1st Class", "2nd Class", "3rd Class"],rotation=45)
plt.legend(title="Survival Status", labels=["Not Survived", "Survived"])

for p in g.patches:
    width = p.get_width()  
    if width > 0:         
        g.annotate(f'{int(width)}', 
                    (width, p.get_y() + p.get_height() / 2.),  
                    ha='left', va='center',                
                    xytext=(5, 0),
                    textcoords='offset points')

plt.show()

# %% [markdown]
# Q2. Boxplot

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(data=titanic,x="pclass",y="age",color="blue", alpha=0.5, size=6)
sns.boxplot(data=titanic,x="pclass",y="age",palette="coolwarm")
plt.xlabel("Passenger Class")
plt.ylabel("Age")
plt.title("Age Distribution by Passenger Class")
plt.xticks(rotation=30)
plt.show()
# Out:
# /var/folders/cq/c1zfg3bd3593rxxcsm4wznwr0000gn/T/ipykernel_5071/2165107237.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=titanic,x="pclass",y="age",palette="coolwarm")

# %% [markdown]
# Q3. Violin Plot

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=titanic,y="fare",hue="sex",split=True,alpha=0.9,inner="quartile",palette=["blue","pink"])
plt.xlabel("Sex")
plt.ylabel("Fare")
plt.title("Fare Distribution by Sex")
plt.show()

# %%
sns.countplot(data=titanic,x="sex",palette=["red","green"])
# Out:
# /var/folders/cq/c1zfg3bd3593rxxcsm4wznwr0000gn/T/ipykernel_5071/497449619.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic,x="sex",palette=["red","green"])
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(data=titanic, x="pclass", y="fare", hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>
